# %% [markdown]
# # Project Details

# %% [markdown]
# # 1: Loading data ;

# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns; sns.set()
import json

# %% [markdown]
# # 2: Gathering data ;
#    ### * Importing enhanced twitter archive

# %%
#load twitter archive file
twt_archive = pd.read_csv('twitter-archive-enhanced.csv')

# %% [markdown]
#    ### ** Downloading twitter image predictions

# %%
url ='https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response=requests.get(url)

with open('image-predictions.tsv', mode='wb') as file:
    file.write(response.content)

# %% [markdown]
#    ### *** Getting tweet-json file

# %%
import json
df_list= []

with open ('tweet-json') as file:
    for line in file:
        df_list.append(json.loads(line))

print(df_list[0])
# Out:
# {'created_at': 'Tue Aug 01 16:23:56 +0000 2017', 'id': 892420643555336193, 'id_str': '892420643555336193', 'full_text': "This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU", 'truncated': False, 'display_text_range': [0, 85], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 892420639486877696, 'id_str': '892420639486877696', 'indices': [86, 109], 'media_url': 'http://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg', 'url': 'https://t.co/MgUWQ76dJU', 'display_url': 'pic.twitter.com/MgUWQ76dJU', 'expanded_url': 'https://twitter.com/dog_rates/status/892420643555336193/photo/1', 'type': 'photo', 'sizes': {'large': {'w': 540, 'h': 528, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 540, 'h': 528, 'resize': 'fit'}, 'medium': {'w': 540, 'h': 528, 'resize': 'fit'}}}]}, 'extended_entities': {'med
# ...

# %%
twt= pd.DataFrame(df_list)

# %%
twt.to_csv('twt_data.csv',index=False)

# %%
twt_data= pd.read_csv('twt_data.csv')

# %% [markdown]
# # 3: Assessing Data ;
#
# ##### Two types of assessment are used:
# ###### *Visual assessment:
# each piece of gathered data is displayed in the Jupyter Notebook for visual assessment purposes. Once displayed, data can additionally be assessed in an external application (e.g. Excel, text editor).
# ###### **Programmatic assessment:
# pandas' functions and/or methods are used to assess the data.
# ###### ***At least eight (8) data quality issues and two (2) tidiness issues are detected,
# and include the issues to clean to satisfy the Project Motivation. Each issue is documented in one to a few sentences each.

# %% [markdown]
# ### * 1 Assesing (twitter-archive-enhanced) data *

# %%
twt_archive.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
twt_archive.sample(8)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1666  682697186228989953                    NaN                  NaN
# 1275  709179584944730112                    NaN                  NaN
# 692   787111942498508800                    NaN                  NaN
# 161   860563773140209665                    NaN                  NaN
# 444   819238181065359361                    NaN                  NaN
# 1109  733828123016450049                    NaN                  NaN
# 1582  687109925361856513                    NaN                  NaN
# 985   749075273010798592                    NaN                  NaN
#
#                       timestamp  \
# 1666  2015-12-31 22:57:47 +0000
# 1275  2016-03-14 00:49:23 +0000
# 692   2016-10-15 02:04:45 +0000
# 161   2017-05-05 18:36:06 +0000
# 444   2017-01-11 17:42:57 +0000
# 1109  2016-05-21 01:13:53 +0000
# 1582  2016-01-13 03:12:26 +0000
# 985   2016-07-02 03:00:36 +0000
#
# ...

# %%
twt_archive.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo'],
#       dtype='object')

# %%
twt_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
#rating_numerator
twt_archive.name.value_counts()
# Out:
# None         745
# a             55
# Charlie       12
# Cooper        11
# Oliver        11
# Lucy          11
# Lola          10
# Tucker        10
# Penny         10
# Bo             9
# Winston        9
# the            8
# Sadie          8
# Bailey         7
# Daisy          7
# an             7
# Buddy          7
# Toby           7
# Jack           6
# Scout          6
# Oscar          6
# Milo           6
# Dave           6
# Bella          6
# Rusty          6
# Koda           6
# Stanley        6
# Leo            6
# Jax            6
# Sammy          5
#             ...
# Butters        1
# Shiloh         1
# Bauer          1
# Mark           1
# Akumi          1
# Maxwell        1
# Batdog         1
# Dale           1
# Eleanor        1
# Joshwa         1
# Storkson       1
# Sage           1
# Rooney         1
# Tiger          1
# Stefan         1
# Marvin         1
# Richie         1
# Pluto          1
# Perry          1
# Billl          1
# Sprinkles      1
# ...

# %%
#no duplicated raws
twt_archive.duplicated().sum()
# Out:
# 0

# %%
twt_archive[twt_archive.name.str.islower()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 22    887517139158093824                    NaN                  NaN
# 56    881536004380872706                    NaN                  NaN
# 118   869988702071779329                    NaN                  NaN
# 169   859196978902773760                    NaN                  NaN
# 193   855459453768019968                    NaN                  NaN
# 335   832645525019123713                    NaN                  NaN
# 369   828650029636317184                    NaN                  NaN
# 542   806219024703037440                    NaN                  NaN
# 649   792913359805018113                    NaN                  NaN
# 682   788552643979468800                    NaN                  NaN
# 759   778396591732486144                    NaN                  NaN
# 773   776249906839351296                    NaN                  NaN
# 801   772581559778025472                    NaN                  NaN
# ...

# %%
twt_archive[['rating_numerator', 'rating_denominator']].describe()
# Out:
#        rating_numerator  rating_denominator
# count       2356.000000         2356.000000
# mean          13.126486           10.455433
# std           45.876648            6.745237
# min            0.000000            0.000000
# 25%           10.000000           10.000000
# 50%           11.000000           10.000000
# 75%           12.000000           10.000000
# max         1776.000000          170.000000

# %%
#rating_numerator
twt_archive.rating_numerator.value_counts()
# Out:
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 1         9
# 2         9
# 420       2
# 0         2
# 15        2
# 75        2
# 80        1
# 20        1
# 24        1
# 26        1
# 44        1
# 50        1
# 60        1
# 165       1
# 84        1
# 88        1
# 144       1
# 182       1
# 143       1
# 666       1
# 960       1
# 1776      1
# 17        1
# 27        1
# 45        1
# 99        1
# 121       1
# 204       1
# Name: rating_numerator, dtype: int64

# %%
# looking for numerators with wrong values in chunks
twt_archive[twt_archive.rating_numerator <= 5].loc[0:1000, :]
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 45   883482846933004288                    NaN                  NaN
# 315  835152434251116546                    NaN                  NaN
# 605  798576900688019456                    NaN                  NaN
# 730  781661882474196992                    NaN                  NaN
# 765  777885040357281792                    NaN                  NaN
# 883  760252756032651264                    NaN                  NaN
# 912  757596066325864448                    NaN                  NaN
# 956  751583847268179968                    NaN                  NaN
#
#                      timestamp  \
# 45   2017-07-08 00:28:19 +0000
# 315  2017-02-24 15:40:31 +0000
# 605  2016-11-15 17:22:24 +0000
# 730  2016-09-30 01:08:10 +0000
# 765  2016-09-19 15:00:20 +0000
# 883  2016-08-01 23:15:56 +0000
# 912  2016-07-25 15:19:12 +0000
# 956  2016-07-09 01:08:47 +0000
#
#                                                 source  \
# ...

# %%
twt_archive[twt_archive.rating_numerator <= 5].loc[1000:2000, :]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1004  747816857231626240                    NaN                  NaN
# 1016  746906459439529985           7.468859e+17         4.196984e+09
# 1165  722974582966214656                    NaN                  NaN
# 1189  718246886998687744                    NaN                  NaN
# 1219  714631576617938945                    NaN                  NaN
# 1249  711306686208872448                    NaN                  NaN
# 1303  707420581654872064                    NaN                  NaN
# 1314  706901761596989440                    NaN                  NaN
# 1399  699691744225525762                    NaN                  NaN
# 1406  699088579889332224                    NaN                  NaN
# 1446  696490539101908992           6.964887e+17         4.196984e+09
# 1459  695064344191721472                    NaN                  NaN
# 1461  694925794720792577                    NaN                  NaN
# ...

# %%
twt_archive[twt_archive.rating_numerator <= 5].loc[2000:, :]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2013  672231046314901505                    NaN                  NaN
# 2026  671879137494245376                    NaN                  NaN
# 2038  671550332464455680           6.715449e+17         4.196984e+09
# 2063  671159727754231808                    NaN                  NaN
# 2070  671122204919246848                    NaN                  NaN
# 2076  670838202509447168                    NaN                  NaN
# 2079  670826280409919488                    NaN                  NaN
# 2091  670783437142401025                    NaN                  NaN
# 2092  670782429121134593                    NaN                  NaN
# 2109  670449342516494336                    NaN                  NaN
# 2134  670069087419133954                    NaN                  NaN
# 2136  670055038660800512                    NaN                  NaN
# 2139  670037189829525505                    NaN                  NaN
# ...

# %%
# id_number == 666033412701032449
twt_archive.loc[(twt_archive.tweet_id == 666033412701032449), 'rating_numerator']
# Out:
# 2353    9
# Name: rating_numerator, dtype: int64

# %%
# tweet text
twt_archive.loc[45,'text']
# Out:
# 'This is Bella. She hopes her smile made you smile. If not, she is also offering you her favorite monkey. 13.5/10 https://t.co/qjrljjt948'

# %%
twt_archive.loc[(twt_archive.tweet_id == 883482846933004288), 'rating_numerator']
# Out:
# 45    5
# Name: rating_numerator, dtype: int64

# %%
# tweet text
twt_archive.loc[2353,'text']
# Out:
# 'Here is a very happy pup. Big fan of well-maintained decks. Just look at that tongue. 9/10 would cuddle af https://t.co/y671yMhoiR'

# %%
# rating_denominator
twt_archive.rating_denominator.describe()
# Out:
# count    2356.000000
# mean       10.455433
# std         6.745237
# min         0.000000
# 25%        10.000000
# 50%        10.000000
# 75%        10.000000
# max       170.000000
# Name: rating_denominator, dtype: float64

# %%
# rating_denominator
twt_archive.rating_denominator.value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
# checking with ids have denominator == 170
twt_archive[twt_archive.rating_denominator == 170].tweet_id
# Out:
# 1120    731156023742988288
# Name: tweet_id, dtype: int64

# %%
# tweet text
twt_archive.loc[1120,'text']
# Out:
# 'Say hello to this unbelievably well behaved squad of doggos. 204/170 would try to pet all at once https://t.co/yGQI3He3xv'

# %%
#through exploring names,i found (none=745, a=55,..)
twt_archive.name.value_counts()
# Out:
# None         745
# a             55
# Charlie       12
# Cooper        11
# Oliver        11
# Lucy          11
# Lola          10
# Tucker        10
# Penny         10
# Bo             9
# Winston        9
# the            8
# Sadie          8
# Bailey         7
# Daisy          7
# an             7
# Buddy          7
# Toby           7
# Jack           6
# Scout          6
# Oscar          6
# Milo           6
# Dave           6
# Bella          6
# Rusty          6
# Koda           6
# Stanley        6
# Leo            6
# Jax            6
# Sammy          5
#             ...
# Butters        1
# Shiloh         1
# Bauer          1
# Mark           1
# Akumi          1
# Maxwell        1
# Batdog         1
# Dale           1
# Eleanor        1
# Joshwa         1
# Storkson       1
# Sage           1
# Rooney         1
# Tiger          1
# Stefan         1
# Marvin         1
# Richie         1
# Pluto          1
# Perry          1
# Billl          1
# Sprinkles      1
# ...

# %% [markdown]
# ### * * 2 Assesing twitter (image-predictions) data * *

# %%
img_pred= pd.read_csv('image-predictions.tsv', sep='\t')
img_pred.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
img_pred.sample(8)
# Out:
#                 tweet_id                                          jpg_url  \
# 748   687807801670897665  https://pbs.twimg.com/media/CYuVi9pWwAAbOGC.jpg
# 1135  728751179681943552  https://pbs.twimg.com/media/Ch0LVPdW0AEdHgU.jpg
# 169   668989615043424256  https://pbs.twimg.com/media/CUi6geuUYAIvE9n.jpg
# 979   707297311098011648  https://pbs.twimg.com/media/CdDTJLMW4AEST--.jpg
# 2002  876838120628539392  https://pbs.twimg.com/media/DCsnnZsVwAEfkyi.jpg
# 227   670374371102445568  https://pbs.twimg.com/media/CU2l7yvXAAUyYIJ.jpg
# 333   672160042234327040  https://pbs.twimg.com/media/CVP9_beUEAAwURR.jpg
# 1676  813172488309972993  https://pbs.twimg.com/media/C0j4EESUsAABtMq.jpg
#
#       img_num                         p1   p1_conf  p1_dog                p2  \
# 748         1  Staffordshire_bullterrier  0.151113    True             boxer
# 1135        1              Saint_Bernard  0.482050    True            collie
# ...

# %%
img_pred.columns
# Out:
# Index(['tweet_id', 'jpg_url', 'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2',
#        'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog'],
#       dtype='object')

# %%
img_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
img_pred.img_num.value_counts()
# Out:
# 1    1780
# 2     198
# 3      66
# 4      31
# Name: img_num, dtype: int64

# %%
img_pred.p1.unique()
# Out:
# array(['Welsh_springer_spaniel', 'redbone', 'German_shepherd',
#        'Rhodesian_ridgeback', 'miniature_pinscher', 'Bernese_mountain_dog',
#        'box_turtle', 'chow', 'shopping_cart', 'miniature_poodle',
#        'golden_retriever', 'Gordon_setter', 'Walker_hound', 'pug',
#        'bloodhound', 'Lhasa', 'English_setter', 'hen', 'desktop_computer',
#        'Italian_greyhound', 'Maltese_dog', 'three-toed_sloth', 'ox',
#        'malamute', 'guinea_pig', 'soft-coated_wheaten_terrier',
#        'Chihuahua', 'black-and-tan_coonhound', 'coho', 'toy_terrier',
#        'Blenheim_spaniel', 'Pembroke', 'llama', 'Chesapeake_Bay_retriever',
#        'curly-coated_retriever', 'dalmatian', 'Ibizan_hound',
#        'Border_collie', 'Labrador_retriever', 'seat_belt', 'snail',
#        'miniature_schnauzer', 'Airedale', 'triceratops', 'swab', 'hay',
#        'hyena', 'jigsaw_puzzle', 'West_Highland_white_terrier',
#        'toy_poodle', 'giant_schnauzer', 'vizsla', 'vacuum', 'Rottweiler',
# ...

# %%
#no duplicated raws
img_pred.duplicated().sum()
# Out:
# 0

# %%
# check probability of 'zebra' photo is really false
img_pred.loc[297,'jpg_url']
# Out:
# 'https://pbs.twimg.com/media/CVFBzpXVEAAHIOv.jpg'

# %%
# it was really 'zebra' photo :)
from IPython.display import Image
Image(url= 'https://pbs.twimg.com/media/CVFBzpXVEAAHIOv.jpg')
# Out:
# <img src="https://pbs.twimg.com/media/CVFBzpXVEAAHIOv.jpg"/>

# %%
img_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %% [markdown]
# ### * * * 3 Assesing (tweet-json) data * * *

# %%
#nothing missing
twt_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 31 columns):
# contributors                     0 non-null float64
# coordinates                      0 non-null float64
# created_at                       2354 non-null object
# display_text_range               2354 non-null object
# entities                         2354 non-null object
# extended_entities                2073 non-null object
# favorite_count                   2354 non-null int64
# favorited                        2354 non-null bool
# full_text                        2354 non-null object
# geo                              0 non-null float64
# id                               2354 non-null int64
# id_str                           2354 non-null int64
# in_reply_to_screen_name          78 non-null object
# in_reply_to_status_id            78 non-null float64
# in_reply_to_status_id_str        78 non-null float64
# in_reply_to_user_id              78 non-null float64
# ...

# %%
twt_data.head()
# Out:
#    contributors  coordinates                      created_at  \
# 0           NaN          NaN  Tue Aug 01 16:23:56 +0000 2017
# 1           NaN          NaN  Tue Aug 01 00:17:27 +0000 2017
# 2           NaN          NaN  Mon Jul 31 00:18:03 +0000 2017
# 3           NaN          NaN  Sun Jul 30 15:58:51 +0000 2017
# 4           NaN          NaN  Sat Jul 29 16:00:24 +0000 2017
#
#   display_text_range                                           entities  \
# 0            [0, 85]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1           [0, 138]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2           [0, 121]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3            [0, 79]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4           [0, 138]  {'hashtags': [{'text': 'BarkWeek', 'indices': ...
#
#                                    extended_entities  favorite_count  \
# 0  {'media': [{'id': 892420639486877696, 'id_str'...           39467
# ...

# %%
twt_data.sample(8)
# Out:
#       contributors  coordinates                      created_at  \
# 722            NaN          NaN  Mon Oct 03 15:42:44 +0000 2016
# 1128           NaN          NaN  Sun May 08 00:59:46 +0000 2016
# 1136           NaN          NaN  Thu May 05 01:35:26 +0000 2016
# 1186           NaN          NaN  Fri Apr 08 15:05:29 +0000 2016
# 1434           NaN          NaN  Wed Feb 10 03:05:46 +0000 2016
# 129            NaN          NaN  Tue May 23 17:40:04 +0000 2017
# 263            NaN          NaN  Thu Mar 16 00:00:07 +0000 2017
# 2144           NaN          NaN  Thu Nov 26 16:59:01 +0000 2015
#
#      display_text_range                                           entities  \
# 722             [0, 97]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1128            [0, 26]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1136            [0, 60]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1186           [0, 139]  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...

# %%
twt_data.lang.value_counts()
# Out:
# en     2336
# und       7
# in        3
# nl        3
# eu        1
# es        1
# et        1
# ro        1
# tl        1
# Name: lang, dtype: int64

# %%
#no duplicated raws
twt_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 1: Quality ;
#
# ## *A Enhanced Twitter Archive:
# ### _AQ1 Replace 'None' with `np.nan` for Columns (`doggo`, `floofer`, `pupper`, `puppo`).
# ### _AQ2 Extract rating scores correctly from tweet text using RegEx and convert it to float.
# ### _AQ3 Convert `timestamp` column to datetime.

# %% [markdown]
# ### _AQ4 Remove retweets and replies.
# ### _AQ5 Remove any rows not related to dogs.
# ### _AQ6 :
# #### - Replace 'None' with np.nan in clean_twt_archive `name` column.
# #### - Remove any rows with invalid names which starts with lower letters.
# ### _AQ7 :Extract tweet source from `source` column

# %% [markdown]
# ## **B twitter image predictions:
#
# ### __BQ1 Some p names start with lowercase letters covert it to uppercase

# %% [markdown]
# ## ***C Tweet data:
#
# ### ___CQ3 Rename `id` column in clean_twt_data to `tweet_id`

# %% [markdown]
# # 2: Tidiness ;
# ## * clean_twt_archive
# ### ____T1 Create `dog_stage` column and remove the (`doggo`, `floofer`, `pupper`, `puppo`) columns.
# ## * clean_twt_data
# ### ____T2 Remove unnecessary columns for clean_twt_data.
# ## * clean_img_pred
# ### ____T3 Remove `img_num` column from clean_img_pred.
# ## * clean_twt_archive / clean_twt_data / clean_img_pred
# ### ____T4    All data is related but devided into 3 dataframes.

# %% [markdown]
# # 4: Cleaning Data ;

# %% [markdown]
# ## * 1 Creating Dataframe copies *

# %%
clean_twt_archive =twt_archive.copy()
clean_img_pred =img_pred.copy()
clean_twt_data =twt_data.copy()

# %%
# show 3 column from databases
display(clean_twt_archive.head(3),
clean_img_pred.head(3),
clean_twt_data.head(3))
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# ...

# %% [markdown]
# # * Cleaning Quality issues *
# ## *A Enhanced Tweetter Archive:
#
# ### Define
# ### _AQ1 Replace 'None' with `np.nan` for Columns (`doggo`, `floofer`, `pupper`, `puppo`).
# ###  Code

# %%
col_list = ['doggo', 'floofer', 'pupper', 'puppo']

for col in col_list:
    clean_twt_archive[col] = clean_twt_archive[col].replace('None', np.nan)

# %% [markdown]
# ### Test

# %%
clean_twt_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         97 non-null object
# floofer                       10 non-null object
# pupper                        257 non-null object
# ...

# %% [markdown]
# ### Define
# ### _AQ2 Extract rating scores correctly from tweet text using RegEx and convert it to float.
# ### Code

# %%
clean_twt_archive[clean_twt_archive.text.str.contains(r"(\d+\.\d*\/\d+)")][['text', 'rating_numerator']]
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
#                                                    text  rating_numerator
# 45    This is Bella. She hopes her smile made you sm...                 5
# 340   RT @dog_rates: This is Logan, the Chow who liv...                75
# 695   This is Logan, the Chow who lived. He solemnly...                75
# 763   This is Sophie. She's a Jubilant Bush Pupper. ...                27
# 1689  I've been told there's a slight possibility he...                 5
# 1712  Here we have uncovered an entire battalion of ...                26

# %%
new_ratings = clean_twt_archive[clean_twt_archive.text.str.contains(r"(\d+\.\d*\/\d+)")]['text'].str.extract(r"(\d+\.\d*(?=\/\d+))")
new_ratings
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
#           0
# 45     13.5
# 340    9.75
# 695    9.75
# 763   11.27
# 1689    9.5
# 1712  11.26

# %%
clean_twt_archive.loc[new_ratings.index, 'rating_numerator'] = new_ratings.values

# %%
clean_twt_archive.rating_numerator = clean_twt_archive.rating_numerator.astype('float')

# %% [markdown]
# ### Test

# %%
clean_twt_archive.loc[new_ratings.index]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 45    883482846933004288                    NaN                  NaN
# 340   832215909146226688                    NaN                  NaN
# 695   786709082849828864                    NaN                  NaN
# 763   778027034220126208                    NaN                  NaN
# 1689  681340665377193984           6.813394e+17         4.196984e+09
# 1712  680494726643068929                    NaN                  NaN
#
#                       timestamp  \
# 45    2017-07-08 00:28:19 +0000
# 340   2017-02-16 13:11:49 +0000
# 695   2016-10-13 23:23:56 +0000
# 763   2016-09-20 00:24:34 +0000
# 1689  2015-12-28 05:07:27 +0000
# 1712  2015-12-25 21:06:00 +0000
#
#                                                  source  \
# 45    <a href="http://twitter.com/download/iphone" r...
# 340   <a href="http://twitter.com/download/iphone" r...
# 695   <a href="http://twitter.com/download/iphone" r...
# ...

# %% [markdown]
# ### Define
# ### _AQ3 Convert `timestamp` column to datetime.
# ### Code

# %%
clean_twt_archive.timestamp = pd.to_datetime(clean_twt_archive.timestamp)

# %% [markdown]
# ### Test

# %%
clean_twt_archive.timestamp.dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ### Define
# ### _AQ4 Remove retweets and replies.
# ### Code

# %%
clean_twt_archive = clean_twt_archive.query('in_reply_to_status_id == "NaN" &\
                                                     in_reply_to_user_id == "NaN" &\
                                                    retweeted_status_id == "NaN" &\
                                                    retweeted_status_user_id == "NaN"')
# drop columns
cols = ['in_reply_to_status_id','in_reply_to_user_id','retweeted_status_id',
           'retweeted_status_user_id', 'retweeted_status_timestamp']
clean_twt_archive.drop(columns = cols, axis=1, inplace=True)

# %% [markdown]
# ### Test

# %%
# check for Null values in the df_arch_cleaned
clean_twt_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 12 columns):
# tweet_id              2097 non-null int64
# timestamp             2097 non-null datetime64[ns]
# source                2097 non-null object
# text                  2097 non-null object
# expanded_urls         2094 non-null object
# rating_numerator      2097 non-null float64
# rating_denominator    2097 non-null int64
# name                  2097 non-null object
# doggo                 83 non-null object
# floofer               10 non-null object
# pupper                230 non-null object
# puppo                 24 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(8)
# memory usage: 213.0+ KB

# %% [markdown]
# ### Define
# ### _AQ5 Remove any rows not related to dogs
# ### Code

# %%
clean_twt_archive = clean_twt_archive[~clean_twt_archive.text.isnull()]

# %%
clean_twt_archive = clean_twt_archive.loc[~clean_twt_archive.text.str.match('.*only rate dogs')]

# %% [markdown]
# ### Test

# %%
clean_twt_archive.loc[clean_twt_archive.text.str.match('.*only rate dogs')]
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
clean_twt_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2043 entries, 0 to 2355
# Data columns (total 12 columns):
# tweet_id              2043 non-null int64
# timestamp             2043 non-null datetime64[ns]
# source                2043 non-null object
# text                  2043 non-null object
# expanded_urls         2040 non-null object
# rating_numerator      2043 non-null float64
# rating_denominator    2043 non-null int64
# name                  2043 non-null object
# doggo                 83 non-null object
# floofer               10 non-null object
# pupper                230 non-null object
# puppo                 24 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(8)
# memory usage: 207.5+ KB

# %% [markdown]
# ### Define
# ### _AQ6 :
# #### - Replace 'None' with np.nan in clean_twt_archive `name` column.
# #### - Remove any rows with invalid names which starts with lower laters.
# ### Code

# %%
clean_twt_archive[~clean_twt_archive.name.str.istitle()].name.unique()
# Out:
# array(['such', 'a', 'not', 'one', 'BeBe', 'DonDon', 'my', 'his', 'an',
#        'actually', 'just', 'mad', 'this', 'all', 'old', 'infuriating',
#        'CeCe', 'the', 'by', 'officially', 'life', 'light', 'space', 'JD',
#        'DayZ', 'quite'], dtype=object)

# %%
clean_twt_archive.name.replace(['such', 'a', 'quite', 'not', 'one', 'incredibly', 'mad',
       'an', 'very', 'just', 'my', 'his', 'actually', 'getting',
       'this', 'unacceptable', 'all', 'old', 'infuriating', 'the',
       'by', 'officially', 'life', 'light', 'space', 'None'], np.nan, inplace=True)

# %% [markdown]
# ### Test

# %%
clean_twt_archive.name.unique()
# Out:
# array(['Phineas', 'Tilly', 'Archie', 'Darla', 'Franklin', nan, 'Jax',
#        'Zoey', 'Cassie', 'Koda', 'Bruno', 'Ted', 'Stuart', 'Oliver', 'Jim',
#        'Zeke', 'Ralphus', 'Gerald', 'Jeffrey', 'Canela', 'Maya', 'Mingus',
#        'Derek', 'Roscoe', 'Waffles', 'Jimbo', 'Maisey', 'Earl', 'Lola',
#        'Kevin', 'Yogi', 'Noah', 'Bella', 'Grizzwald', 'Rusty', 'Gus',
#        'Stanley', 'Alfy', 'Koko', 'Rey', 'Gary', 'Elliot', 'Louis',
#        'Jesse', 'Romeo', 'Bailey', 'Duddles', 'Jack', 'Steven', 'Beau',
#        'Snoopy', 'Shadow', 'Emmy', 'Aja', 'Penny', 'Dante', 'Nelly',
#        'Ginger', 'Benedict', 'Venti', 'Goose', 'Nugget', 'Cash', 'Jed',
#        'Sebastian', 'Sierra', 'Monkey', 'Harry', 'Kody', 'Lassie', 'Rover',
#        'Napolean', 'Boomer', 'Cody', 'Rumble', 'Clifford', 'Dewey',
#        'Scout', 'Gizmo', 'Walter', 'Cooper', 'Harold', 'Shikha', 'Lili',
#        'Jamesy', 'Coco', 'Sammy', 'Meatball', 'Paisley', 'Albus',
# ...

# %%
clean_twt_archive.name.value_counts()
# Out:
# Lucy            11
# Charlie         11
# Oliver          10
# Cooper          10
# Tucker           9
# Penny            9
# Lola             8
# Winston          8
# Sadie            8
# Daisy            7
# Toby             7
# Koda             6
# Oscar            6
# Bella            6
# Bo               6
# Bailey           6
# Jax              6
# Stanley          6
# Rusty            5
# Louis            5
# Scout            5
# Milo             5
# Chester          5
# Dave             5
# Leo              5
# Buddy            5
# Bentley          5
# George           4
# Brody            4
# Chip             4
#                 ..
# Hubertson        1
# Bobb             1
# Claude           1
# Eevee            1
# Gidget           1
# Sprinkles        1
# Fiji             1
# Perry            1
# Alexanderson     1
# Griswold         1
# Sandra           1
# Tycho            1
# Longfellow       1
# Bruiser          1
# Mike             1
# Gustaf           1
# ...

# %%
clean_twt_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2043 entries, 0 to 2355
# Data columns (total 12 columns):
# tweet_id              2043 non-null int64
# timestamp             2043 non-null datetime64[ns]
# source                2043 non-null object
# text                  2043 non-null object
# expanded_urls         2040 non-null object
# rating_numerator      2043 non-null float64
# rating_denominator    2043 non-null int64
# name                  1389 non-null object
# doggo                 83 non-null object
# floofer               10 non-null object
# pupper                230 non-null object
# puppo                 24 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(8)
# memory usage: 207.5+ KB

# %% [markdown]
# ### Define
# ### _AQ7 :Extract tweet source from `source` column
# ### Code

# %%
# check for the unique values
clean_twt_archive.source.unique()
# Out:
# array([ '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#        '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#        '<a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>',
#        '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>'], dtype=object)

# %%
#make a function fix_source which extract the strings between tags
def fix_source(x):
    i= x.find('>') + 1
    j =x[i:].find('<')
    # extract the text in between
    return x[i:][:j]

# %%
clean_twt_archive.source = clean_twt_archive.source.apply(lambda x: fix_source(x)).astype('category')

# %% [markdown]
# ### Test

# %%
# check for the unique values
clean_twt_archive.source.unique()
# Out:
# [Twitter for iPhone, Twitter Web Client, Vine - Make a Scene, TweetDeck]
# Categories (4, object): [Twitter for iPhone, Twitter Web Client, Vine - Make a Scene, TweetDeck]

# %% [markdown]
# ## **B Tweet image predictions:
#
# ### Define
# ### __BQ1 Some p names start with lowercase letters covert it to uppercase.
#
# ###  Code

# %%
clean_img_pred.p1 =clean_img_pred.p1.str.title()
clean_img_pred.p2 =clean_img_pred.p1.str.title()
clean_img_pred.p3 =clean_img_pred.p1.str.title()

# %% [markdown]
# ### Test

# %%
clean_img_pred.p1.sample(8)
# Out:
# 970                   Chow
# 1020            Cowboy_Hat
# 1585              Pembroke
# 1475                   Pug
# 650     Labrador_Retriever
# 1377              Malamute
# 459     Labrador_Retriever
# 1697             Chihuahua
# Name: p1, dtype: object

# %%
clean_img_pred.p2.sample(8)
# Out:
# 787                        Kuvasz
# 1654    Staffordshire_Bullterrier
# 1154                        Koala
# 1494                     Cardigan
# 445         Flat-Coated_Retriever
# 876             Italian_Greyhound
# 1785    Staffordshire_Bullterrier
# 668                         Boxer
# Name: p2, dtype: object

# %%
clean_img_pred.p3.sample(8)
# Out:
# 865                 Labrador_Retriever
# 180                   Golden_Retriever
# 1461                       Boston_Bull
# 1746                           Samoyed
# 1468                    Cocker_Spaniel
# 1582    American_Staffordshire_Terrier
# 1562                  Golden_Retriever
# 716                   Lakeland_Terrier
# Name: p3, dtype: object

# %%
# check if lettwe in all words in p1 is uppercase
(clean_img_pred.p1.str.istitle()).value_counts()
# Out:
# True    2075
# Name: p1, dtype: int64

# %%
# check if lettwe in all words in p2 is uppercase
(clean_img_pred.p2.str.istitle()).value_counts()
# Out:
# True    2075
# Name: p2, dtype: int64

# %%
# check if lettwe in all words in p3 is uppercase
(clean_img_pred.p3.str.istitle()).value_counts()
# Out:
# True    2075
# Name: p3, dtype: int64

# %% [markdown]
# # 2: Tidiness ;
#
# ### Define
# ### ___T1 Create `dog_stage` column and remove the (`doggo`, `floofer`, `pupper`, `puppo`) columns.
# ### Code

# %%
# select the dog stages columns from the dataset
cols = ['doggo', 'floofer', 'pupper', 'puppo']

# create the dog_stage column with joining the four columns in one column dog_stage join for more than stage
clean_twt_archive['dog_stage'] = clean_twt_archive[cols].\
                                        apply(lambda x: ', '.join(x.dropna().astype(str)),axis =1)
# replace the empty string with nan and change datatype to category
clean_twt_archive.dog_stage = clean_twt_archive.dog_stage.replace('', np.nan).astype('category')

# drop the 4 columns
clean_twt_archive = clean_twt_archive.drop(columns = cols, axis =1)

# %% [markdown]
# ### Test

# %%
clean_twt_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2043 entries, 0 to 2355
# Data columns (total 9 columns):
# tweet_id              2043 non-null int64
# timestamp             2043 non-null datetime64[ns]
# source                2043 non-null category
# text                  2043 non-null object
# expanded_urls         2040 non-null object
# rating_numerator      2043 non-null float64
# rating_denominator    2043 non-null int64
# name                  1389 non-null object
# dog_stage             336 non-null category
# dtypes: category(2), datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 132.2+ KB

# %%
clean_twt_archive.dog_stage.value_counts()
# Out:
# pupper            221
# doggo              72
# puppo              23
# floofer             9
# doggo, pupper       9
# doggo, puppo        1
# doggo, floofer      1
# Name: dog_stage, dtype: int64

# %% [markdown]
# ### Define
# ### ___T2 Remove unnecessary columns for clean_twt_data.
# ### Code

# %%
clean_twt_data.columns
# Out:
# Index(['contributors', 'coordinates', 'created_at', 'display_text_range',
#        'entities', 'extended_entities', 'favorite_count', 'favorited',
#        'full_text', 'geo', 'id', 'id_str', 'in_reply_to_screen_name',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status',
#        'lang', 'place', 'possibly_sensitive', 'possibly_sensitive_appealable',
#        'quoted_status', 'quoted_status_id', 'quoted_status_id_str',
#        'retweet_count', 'retweeted', 'retweeted_status', 'source', 'truncated',
#        'user'],
#       dtype='object')

# %%
clean_twt_data = clean_twt_data[['id', 'retweet_count', 'favorite_count','lang']]

# %% [markdown]
# ### Test

# %%
clean_twt_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 4 columns):
# id                2354 non-null int64
# retweet_count     2354 non-null int64
# favorite_count    2354 non-null int64
# lang              2354 non-null object
# dtypes: int64(3), object(1)
# memory usage: 73.6+ KB

# %% [markdown]
# ## ***C Tweet data:
# ### Define
# ### ___CQ1 Rename `id` column in clean_twt_data to `tweet_id`
# ### Code

# %%
clean_twt_data.columns = ['tweet_id', 'retweet_count', 'favorite_count','lang']

# %% [markdown]
# ### Test

# %%
clean_twt_data.columns
# Out:
# Index(['tweet_id', 'retweet_count', 'favorite_count', 'lang'], dtype='object')

# %% [markdown]
# ### Define
# ### ___T3 Remove `img_num` column from clean_img_pred.
# ### Code

# %%
clean_img_pred.drop('img_num', axis=1, inplace=True)

# %% [markdown]
# ### Test

# %%
clean_img_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 11 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(1), object(4)
# memory usage: 135.8+ KB

# %% [markdown]
# ###  Define
#    ###  ____T4    All data is related but devided into 3 dataframes.
# ###  Code

# %%
# Merging enhanced twitter archive with twitter data
clean_twt_archive =pd.merge(clean_twt_archive, clean_twt_data,on='tweet_id',how='left')

# %%
# Merging enhanced twitter archive with img_pred
clean_twt_archive =pd.merge(clean_twt_archive, clean_img_pred,on='tweet_id',how='left')

# %% [markdown]
# ### Test

# %%
clean_twt_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2043 entries, 0 to 2042
# Data columns (total 22 columns):
# tweet_id              2043 non-null int64
# timestamp             2043 non-null datetime64[ns]
# source                2043 non-null category
# text                  2043 non-null object
# expanded_urls         2040 non-null object
# rating_numerator      2043 non-null float64
# rating_denominator    2043 non-null int64
# name                  1389 non-null object
# dog_stage             336 non-null category
# retweet_count         2043 non-null int64
# favorite_count        2043 non-null int64
# lang                  2043 non-null object
# jpg_url               1917 non-null object
# p1                    1917 non-null object
# p1_conf               1917 non-null float64
# p1_dog                1917 non-null object
# p2                    1917 non-null object
# p2_conf               1917 non-null float64
# p2_dog                1917 non-null object
# ...

# %% [markdown]
# # 5: Sorting data ;

# %%
clean_twt_archive.to_csv('twitter_archive_wrangle_act.csv', index=False)

# %% [markdown]
# # 6: Data analysis and visualization ;

# %%
twitter_archive_wrangle = pd.read_csv('twitter_archive_wrangle_act.csv')

# %%
twitter_archive_wrangle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2043 entries, 0 to 2042
# Data columns (total 22 columns):
# tweet_id              2043 non-null int64
# timestamp             2043 non-null object
# source                2043 non-null object
# text                  2043 non-null object
# expanded_urls         2040 non-null object
# rating_numerator      2043 non-null float64
# rating_denominator    2043 non-null int64
# name                  1389 non-null object
# dog_stage             336 non-null object
# retweet_count         2043 non-null int64
# favorite_count        2043 non-null int64
# lang                  2043 non-null object
# jpg_url               1917 non-null object
# p1                    1917 non-null object
# p1_conf               1917 non-null float64
# p1_dog                1917 non-null object
# p2                    1917 non-null object
# p2_conf               1917 non-null float64
# p2_dog                1917 non-null object
# ...

# %% [markdown]
# ## 1: Comparing dog stages ;

# %%
data = twitter_archive_wrangle.groupby('dog_stage').count()['tweet_id']
ax = sns.barplot(y=data.index, x=data.values, palette='Blues_d')
ax.set(xlabel='Count', ylabel='Dog stage', title='Dog Stage Counts')
plt.show()

# %% [markdown]
# ## * Insights.
# ### As we can see ..
# ### 1.Pupper has the highest percentage
# ### 2. Floofer has the lowest percentage

# %% [markdown]
# ## 2: The relation between 'retweet_count' and 'favorite_count' ;

# %%
# Scatter plot to show the relation between favorits and retweets
ax = sns.regplot(x='retweet_count', y='favorite_count', data=twitter_archive_wrangle, fit_reg=False) 
ax.set(xlabel='Retweet count', ylabel='Favorite count', title='Favorits VS Retweets')
plt.show()

# %%
ax = sns.regplot(x='retweet_count', y='favorite_count', data=twitter_archive_wrangle, color='b', scatter_kws={'s':5, 'alpha':.3}) 
ax.set(xlabel='Retweet count', ylabel='Favorite count', title='Favorits VS Retweets')
plt.show()

# %% [markdown]
# ## ** Insights.
# ### As we can see ..
# ### A liner relationship between retweet count and favorite count

# %% [markdown]
# ## 3: Comparing tweets from different sources ;

# %%
data = twitter_archive_wrangle.groupby('source').count()['tweet_id']
ax = sns.barplot(y=data.index, x=data.values, palette='Blues_d')
ax.set(xlabel='Count', ylabel='Tweet source', title='Tweet Source Counts')
plt.show()

# %% [markdown]
# ## *** Insights.
# ### As we can see ..
# ### Most tweetes source is iphone's devices

# %% [markdown]
# ## 4: Most popular languages used in posting Twittes ;

# %%
twitter_archive_wrangle.lang.value_counts()
# Out:
# en     2035
# nl        3
# in        2
# eu        1
# et        1
# und       1
# Name: lang, dtype: int64

# %%
data = twitter_archive_wrangle.groupby('lang').count()['tweet_id']
ax = sns.barplot(y=data.index, x=data.values, palette='Blues_d')
ax.set(xlabel='Count', ylabel='Languages', title='Most popular languages')
plt.show()

# %% [markdown]
# ## **** Insights.
# ### As we can see ..
# ###  Most popular languages used in posting twittes is 'English'
